# %% [markdown]
# # Introduction to pandas
# ## Analyzing the top movies from IMDB

# %%
# run this to import numpy and pandas
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("imdb_1000.csv")

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0      ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1         ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4    ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ..                                                 ...
# 974   ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# 975  ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# 976    ['Russell Crowe', 'Paul Bettany', 'Billy Boyd']
# 977  ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
# 978  ['Charlie Sheen', 'Michael Douglas', 'Tamara T...
#
# [979 rows x 6 columns]

# %%
movies["title"]
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies["star_rating"].mean()
# Out:
# np.float64(7.889785495403474)

# %%
movies["genre"].value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
movies["genre"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='genre'>

# %%
movies.loc[movies["star_rating"] >= 8.0]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 3            9.0           The Dark Knight          PG-13     Action
# 4            8.9              Pulp Fiction              R      Crime
# ..           ...                       ...            ...        ...
# 389          8.0                    Freaks        UNRATED      Drama
# 390          8.0     Letters from Iwo Jima              R      Drama
# 391          8.0          Edge of Tomorrow          PG-13     Action
# 392          8.0                     Glory              R      Drama
# 393          8.0         The African Queen             PG  Adventure
#
#      duration                                        actors_list
# 0         142    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1         175       ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2         200   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3         152  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4         154  ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ..        ...                                                ...
# 389        64  ['Wallace Ford', 'Leila Hyams', 'Olga Baclanova']
# 390       141  ['Ken Watanabe', 'Kazunari Ninomiya', 'Tsuyosh...
# 391       113       ['Tom Cruise', 'Emily Blunt', 'Bill Paxton']
# 392       122  ['Matthew Broderick', 'Denzel Washington', 'Ca...
# 393       105  ['Humphrey Bogart', 'Katharine Hepburn', 'Robe...
#
# [394 rows x 6 columns]

# %%
passengers = pd.read_csv("titanic.csv")

# %%
passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
passengers.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

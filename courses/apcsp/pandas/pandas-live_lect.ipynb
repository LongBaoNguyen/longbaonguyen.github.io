# %% [markdown]
# # Introduction to pandas
# ## Analyzing the top movies from IMDB

# %%
# run this to import numpy and pandas
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("imdb_1000.csv")

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0      ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1         ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4    ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ..                                                 ...
# 974   ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# 975  ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# 976    ['Russell Crowe', 'Paul Bettany', 'Billy Boyd']
# 977  ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
# 978  ['Charlie Sheen', 'Michael Douglas', 'Tamara T...
#
# [979 rows x 6 columns]

# %%
movies["genre"].value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
movies["genre"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='genre'>

# %%
# filtering
movies.loc[movies["star_rating"] >= 8.5]
# Out:
#     star_rating                     title content_rating      genre  duration  \
# 0           9.3  The Shawshank Redemption              R      Crime       142
# 1           9.2             The Godfather              R      Crime       175
# 2           9.1    The Godfather: Part II              R      Crime       200
# 3           9.0           The Dark Knight          PG-13     Action       152
# 4           8.9              Pulp Fiction              R      Crime       154
# ..          ...                       ...            ...        ...       ...
# 58          8.5            Paths of Glory       APPROVED      Drama        88
# 59          8.5          Django Unchained              R    Western       165
# 60          8.5                  3 Idiots          PG-13     Comedy       170
# 61          8.5    Grave of the Fireflies        UNRATED  Animation        89
# 62          8.5               The Shining              R     Horror       146
#
#                                           actors_list
# 0     ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1        ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2    ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3   ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4   ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ..                                                ...
# 58  ['Kirk Douglas', 'Ralph Meeker', 'Adolphe Menjo']
# 59  ['Jamie Foxx', 'Christoph Waltz', 'Leonardo Di...
# 60           ['Aamir Khan', 'Madhavan', 'Mona Singh']
# 61  ['Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi ...
# 62  ['Jack Nicholson', 'Shelley Duvall', 'Danny Ll...
#
# [63 rows x 6 columns]

# %%
movies.loc[movies["content_rating"] == "PG"]
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 30           8.6                                   Spirited Away
# 32           8.6                                      Casablanca
# 37           8.6                         Raiders of the Lost Ark
# ..           ...                                             ...
# 956          7.4                        Manhattan Murder Mystery
# 962          7.4                              Driving Miss Daisy
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
#
#     content_rating      genre  duration  \
# 12              PG     Action       124
# 19              PG     Action       121
# 30              PG  Animation       125
# 32              PG      Drama       102
# 37              PG     Action       115
# ..             ...        ...       ...
# 956             PG     Comedy       104
# 962             PG     Comedy        99
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 977             PG     Horror       114
#
#                                            actors_list
# 12   ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# 19   ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# 30   ['Daveigh Chase', 'Suzanne Pleshette', 'Miyu I...
# 32   ['Humphrey Bogart', 'Ingrid Bergman', 'Paul He...
# 37    ['Harrison Ford', 'Karen Allen', 'Paul Freeman']
# ..                                                 ...
# 956     ['Woody Allen', 'Diane Keaton', 'Jerry Adler']
# 962  ['Morgan Freeman', 'Jessica Tandy', 'Dan Aykro...
# 974   ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# 975  ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# 977  ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
#
# [123 rows x 6 columns]

# %%
titanic = pd.read_csv("titanic_train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
 titanic.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
 titanic.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

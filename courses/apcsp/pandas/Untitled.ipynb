# %% [markdown]
# # Introduction to pandas
# ## Analyzing the top movies from IMDB

# %%
import numpy as np
import pandas as pd

# %%
movies_df = pd.read_csv("imdb_1000.csv")

# %%
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_df["title"]
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies_df["star_rating"].mean()
# Out:
# 7.8897854954034985

# %%
movies_df["star_rating"].std()
# Out:
# 0.336069326147959

# %%
movies_df["genre"].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies_df["genre"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
movies_df["genre"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
movies_df.iloc[:4]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1       ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...

# %%
movies_df.iloc[:4, "title":"duration"]
# Out:
#                       title content_rating   genre  duration
# 0  The Shawshank Redemption              R   Crime       142
# 1             The Godfather              R   Crime       175
# 2    The Godfather: Part II              R   Crime       200
# 3           The Dark Knight          PG-13  Action       152
# 4              Pulp Fiction              R   Crime       154

# %%
movies_df.set_index("title", inplace=True)

# %%
movies_df.iloc[0:4]
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# The Godfather                  ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight           ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...

# %%
movies_df.loc["The Godfather":"The Dark Knight"]
# Out:
#                         star_rating content_rating   genre  duration  \
# title
# The Godfather                   9.2              R   Crime       175
# The Godfather: Part II          9.1              R   Crime       200
# The Dark Knight                 9.0          PG-13  Action       152
#
#                                                               actors_list
# title
# The Godfather                ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight         ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...

# %%
movies_df.loc[movies_df["star_rating"] >= 8.5]
# Out:
#                           star_rating content_rating      genre  duration  \
# title
# The Shawshank Redemption          9.3              R      Crime       142
# The Godfather                     9.2              R      Crime       175
# The Godfather: Part II            9.1              R      Crime       200
# The Dark Knight                   9.0          PG-13     Action       152
# Pulp Fiction                      8.9              R      Crime       154
# ...                               ...            ...        ...       ...
# Paths of Glory                    8.5       APPROVED      Drama        88
# Django Unchained                  8.5              R    Western       165
# 3 Idiots                          8.5          PG-13     Comedy       170
# Grave of the Fireflies            8.5        UNRATED  Animation        89
# The Shining                       8.5              R     Horror       146
#
# ...

# %%
movies_df.loc[movies_df["actors_list"].str.contains("Christian Bale")]
# Out:
#                        star_rating content_rating      genre  duration  \
# title
# The Dark Knight                9.0          PG-13     Action       152
# The Dark Knight Rises          8.5          PG-13     Action       165
# The Prestige                   8.5          PG-13      Drama       130
# Batman Begins                  8.3          PG-13     Action       140
# The Fighter                    7.9              R  Biography       116
# Empire of the Sun              7.8             PG      Drama       153
# 3:10 to Yuma                   7.8              R  Adventure       122
# The Machinist                  7.7              R      Drama       101
# Jin ling shi san chai          7.6              R      Drama       146
# American Psycho                7.6              R      Crime       102
# Equilibrium                    7.6              R     Action       107
#
#                                                              actors_list
# title
# ...

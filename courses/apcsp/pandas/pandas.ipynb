# %% [markdown]
# # Introduction to pandas
# ## Analyzing the top movies from IMDB

# %%
# run this to import numpy and pandas
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("imdb_1000.csv")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1       ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4  ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...

# %%
movies[["title", "genre"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_l/sdgjn0097p96d2br9y_tr4qc0000gp/T/ipykernel_43057/1976323118.py in <module>
# ----> 1 movies[["title", "genre"]]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
movies = movies.set_index("title")

# %%
movies
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
movies.head()
# Out:
#                           star_rating                     title  \
# title
# The Shawshank Redemption          9.3  The Shawshank Redemption
# The Godfather                     9.2             The Godfather
# The Godfather: Part II            9.1    The Godfather: Part II
# The Dark Knight                   9.0           The Dark Knight
# Pulp Fiction                      8.9              Pulp Fiction
#
#                          content_rating   genre  duration  \
# title
# The Shawshank Redemption              R   Crime       142
# The Godfather                         R   Crime       175
# The Godfather: Part II                R   Crime       200
# The Dark Knight                   PG-13  Action       152
# Pulp Fiction                          R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# ...

# %%
movies["genre"].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
pd.__version__
# Out:
# '0.25.3'

# %%
movies.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-65a8234883b8> in <module>
# ----> 1 movies.value_counts()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
genre = movies["genre"].value_counts()
genre
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
type(genre)
# Out:
# pandas.core.series.Series

# %%
genre.plot(kind="bar")

# %%
movies.loc[movies["star_rating"]>9, ["genre", "duration"]]
# Out:
#                           genre  duration
# title
# The Shawshank Redemption  Crime       142
# The Godfather             Crime       175
# The Godfather: Part II    Crime       200

# %%
movies.head()
# Out:
#                           star_rating                     title  \
# title
# The Shawshank Redemption          9.3  The Shawshank Redemption
# The Godfather                     9.2             The Godfather
# The Godfather: Part II            9.1    The Godfather: Part II
# The Dark Knight                   9.0           The Dark Knight
# Pulp Fiction                      8.9              Pulp Fiction
#
#                          content_rating   genre  duration  \
# title
# The Shawshank Redemption              R   Crime       142
# The Godfather                         R   Crime       175
# The Godfather: Part II                R   Crime       200
# The Dark Knight                   PG-13  Action       152
# Pulp Fiction                          R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# ...

# %%
grades_dict = {'Wally': [87, 96, 70], 'Eva': [100, 87,90],'Sam': [94, 77, 90],
'Katie': [100, 81, 82],'Bob': [83, 65, 85]}
grades = pd.DataFrame(grades_dict)
grades
# Out:
#    Wally  Eva  Sam  Katie  Bob
# 0     87  100   94    100   83
# 1     96   87   77     81   65
# 2     70   90   90     82   85

# %%
grades.index = ["Test1", "Test2", "Test3"]

# %%
grades
# Out:
#        Wally  Eva  Sam  Katie  Bob
# Test1     87  100   94    100   83
# Test2     96   87   77     81   65
# Test3     70   90   90     82   85

# %%
grades[grades["Eva"]>=90]["Eva"]
# Out:
# Test1    100
# Test3     90
# Name: Eva, dtype: int64

# %%
grades[grades["Bob"] >= 70]
# Out:
#        Wally  Eva  Sam  Katie  Bob
# Test1     87  100   94    100   83
# Test3     70   90   90     82   85

# %%
movies.head()
# Out:
#                           star_rating                     title  \
# title
# The Shawshank Redemption          9.3  The Shawshank Redemption
# The Godfather                     9.2             The Godfather
# The Godfather: Part II            9.1    The Godfather: Part II
# The Dark Knight                   9.0           The Dark Knight
# Pulp Fiction                      8.9              Pulp Fiction
#
#                          content_rating   genre  duration  \
# title
# The Shawshank Redemption              R   Crime       142
# The Godfather                         R   Crime       175
# The Godfather: Part II                R   Crime       200
# The Dark Knight                   PG-13  Action       152
# Pulp Fiction                          R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# ...

# %%
movies.set_index("title", inplace=True)

# %%
movies
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# The Godfather                  ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight           ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# Pulp Fiction              ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...

# %%
movies.sort_index(ascending=False)
# Out:
#                        star_rating content_rating      genre  duration  \
# title
# [Rec]                          7.5              R     Horror        78
# Zulu                           7.8        UNRATED      Drama       138
# Zombieland                     7.7              R     Comedy        88
# Zodiac                         7.7              R      Crime       157
# Zero Dark Thirty               7.4              R      Drama       157
# ...                            ...            ...        ...       ...
# 2001: A Space Odyssey          8.3              G    Mystery       160
# 127 Hours                      7.6              R  Adventure        94
# 12 Years a Slave               8.1              R  Biography       134
# 12 Angry Men                   8.9      NOT RATED      Drama        96
# (500) Days of Summer           7.8          PG-13     Comedy        95
#
#                                                              actors_list
# title
# ...

# %%
movies.sort_values(by="star_rating", ascending=False)
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
# ...                               ...            ...     ...       ...
# Frances Ha                        7.4              R  Comedy        86
# Home Alone                        7.4             PG  Comedy       103
# Bound                             7.4              R   Crime       108
# Sleepy Hollow                     7.4              R   Drama       105
# Wall Street                       7.4              R   Crime       126
#
#                                                                 actors_list
# title
# ...

# %%
movies[movies["genre"] == "Crime"]
# Out:
#                           star_rating content_rating  genre  duration  \
# title
# The Shawshank Redemption          9.3              R  Crime       142
# The Godfather                     9.2              R  Crime       175
# The Godfather: Part II            9.1              R  Crime       200
# Pulp Fiction                      8.9              R  Crime       154
# City of God                       8.7              R  Crime       130
# ...                               ...            ...    ...       ...
# Brick                             7.5              R  Crime       110
# Mean Streets                      7.4              R  Crime       112
# Bound                             7.4              R  Crime       108
# Law Abiding Citizen               7.4              R  Crime       109
# Wall Street                       7.4              R  Crime       126
#
#                                                                 actors_list
# title
# ...

# %%
movies.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# The Godfather                  ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight           ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# Pulp Fiction              ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...

# %%
movies["star_rating"].mean()
# Out:
# 7.889785495403474

# %%
movies.groupby("genre").mean()
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
movies.groupby("genre")["star_rating"].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Fantasy      7.700000
# Film-Noir    8.033333
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Western      8.255556
# Name: star_rating, dtype: float64

# %%
movies.groupby("genre").mean().sort_values(by="star_rating")
# Out:
#            star_rating    duration
# genre
# Thriller      7.680000  114.200000
# Fantasy       7.700000  112.000000
# Horror        7.806897  102.517241
# Comedy        7.822436  107.602564
# Family        7.850000  107.500000
# Biography     7.862338  131.844156
# Action        7.884559  126.485294
# Drama         7.902518  126.539568
# Animation     7.914516   96.596774
# Crime         7.916935  122.298387
# Sci-Fi        7.920000  109.000000
# Adventure     7.933333  134.840000
# Mystery       7.975000  115.625000
# History       8.000000   66.000000
# Film-Noir     8.033333   97.333333
# Western       8.255556  136.666667

# %%
movies[movies["actors_list"].str.contains("Christian Bale")]
# Out:
#                        star_rating content_rating      genre  duration  \
# title
# The Dark Knight                9.0          PG-13     Action       152
# The Dark Knight Rises          8.5          PG-13     Action       165
# The Prestige                   8.5          PG-13      Drama       130
# Batman Begins                  8.3          PG-13     Action       140
# The Fighter                    7.9              R  Biography       116
# Empire of the Sun              7.8             PG      Drama       153
# 3:10 to Yuma                   7.8              R  Adventure       122
# The Machinist                  7.7              R      Drama       101
# Jin ling shi san chai          7.6              R      Drama       146
# American Psycho                7.6              R      Crime       102
# Equilibrium                    7.6              R     Action       107
#
#                                                              actors_list
# title
# ...

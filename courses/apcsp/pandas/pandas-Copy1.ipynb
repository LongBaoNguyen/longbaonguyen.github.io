# %% [markdown]
# # Introduction to pandas
# ## Analyzing the top movies from IMDB

# %%
# run this to import numpy and pandas
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("imdb_1000.csv")

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0      ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1         ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4    ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ..                                                 ...
# 974   ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# 975  ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# 976    ['Russell Crowe', 'Paul Bettany', 'Billy Boyd']
# 977  ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
# 978  ['Charlie Sheen', 'Michael Douglas', 'Tamara T...
#
# [979 rows x 6 columns]

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1       ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4  ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...

# %%
movies.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974   ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# 975  ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# 976    ['Russell Crowe', 'Paul Bettany', 'Billy Boyd']
# 977  ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
# 978  ['Charlie Sheen', 'Michael Douglas', 'Tamara T...

# %%
movies["title"]
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
movies["genre"].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies["genre"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
movies.iloc[:4]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1       ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...

# %%
mo

# %%
movies = movies.set_index("title")
movies
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
#                                                      genre  duration  \
# title
# The Shawshank Redemption                             Crime       142
# The Godfather                                        Crime       175
# The Godfather: Part II                               Crime       200
# The Dark Knight                                     Action       152
# Pulp Fiction                                         Crime       154
# ...                                                    ...       ...
# Tootsie                                             Comedy       116
# Back to the Future Part III                      Adventure       118
# Master and Commander: The Far Side of the World     Action       138
# Poltergeist                                         Horror       114
# Wall Street                                          Crime       126
#
#                                                                                        actors_list
# title
# The Shawshank Redemption                           ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# The Godfather                                         ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II                            ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight                                  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# Pulp Fiction                                     ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ...                                                                                            ...
# Tootsie                                           ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# Back to the Future Part III                      ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# Master and Commander: The Far Side of the World    ['Russell Crowe', 'Paul Bettany', 'Billy Boyd']
# Poltergeist                                      ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
# Wall Street                                      ['Charlie Sheen', 'Michael Douglas', 'Tamara T...
#
# [979 rows x 5 columns]

# %%
movies.loc["The Godfather":"The Dark Knight"]
# Out:
#                         star_rating content_rating   genre  duration  \
# title
# The Godfather                   9.2              R   Crime       175
# The Godfather: Part II          9.1              R   Crime       200
# The Dark Knight                 9.0          PG-13  Action       152
#
#                                                               actors_list
# title
# The Godfather                ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II   ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight         ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...

# %%
movies.loc[movies["star_rating"] > 8]
# Out:
#                           star_rating content_rating      genre  duration  \
# title
# The Shawshank Redemption          9.3              R      Crime       142
# The Godfather                     9.2              R      Crime       175
# The Godfather: Part II            9.1              R      Crime       200
# The Dark Knight                   9.0          PG-13     Action       152
# Pulp Fiction                      8.9              R      Crime       154
# ...                               ...            ...        ...       ...
# The Manchurian Candidate          8.1       APPROVED    Mystery       126
# Duck Soup                         8.1         PASSED     Comedy        68
# Beauty and the Beast              8.1              G  Animation        84
# The Truman Show                   8.1             PG      Drama       103
# The Wild Bunch                    8.1              R     Action       145
#
#                                                                 actors_list
# title
# The Shawshank Redemption    ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# The Godfather                  ['Marlon Brando', 'Al Pacino', 'James Caan']
# The Godfather: Part II     ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# The Dark Knight           ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# Pulp Fiction              ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# ...                                                                     ...
# The Manchurian Candidate  ['Frank Sinatra', 'Laurence Harvey', 'Janet Le...
# Duck Soup                      ['Groucho Marx', 'Harpo Marx', 'Chico Marx']
# Beauty and the Beast      [u"Paige O'Hara", 'Robby Benson', 'Richard Whi...
# The Truman Show                 ['Jim Carrey', 'Ed Harris', 'Laura Linney']
# The Wild Bunch            ['William Holden', 'Ernest Borgnine', 'Robert ...
#
# [297 rows x 5 columns]

# %%
movies.loc[movies["content_rating"] == "PG"]
# Out:
#                                                 star_rating content_rating  \
# title
# Star Wars: Episode V - The Empire Strikes Back          8.8             PG
# Star Wars                                               8.7             PG
# Spirited Away                                           8.6             PG
# Casablanca                                              8.6             PG
# Raiders of the Lost Ark                                 8.6             PG
# ...                                                     ...            ...
# Manhattan Murder Mystery                                7.4             PG
# Driving Miss Daisy                                      7.4             PG
# Tootsie                                                 7.4             PG
# Back to the Future Part III                             7.4             PG
# Poltergeist                                             7.4             PG
#
#                                                     genre  duration  \
# title
# Star Wars: Episode V - The Empire Strikes Back     Action       124
# Star Wars                                          Action       121
# Spirited Away                                   Animation       125
# Casablanca                                          Drama       102
# Raiders of the Lost Ark                            Action       115
# ...                                                   ...       ...
# Manhattan Murder Mystery                           Comedy       104
# Driving Miss Daisy                                 Comedy        99
# Tootsie                                            Comedy       116
# Back to the Future Part III                     Adventure       118
# Poltergeist                                        Horror       114
#
#                                                                                       actors_list
# title
# Star Wars: Episode V - The Empire Strikes Back  ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# Star Wars                                       ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# Spirited Away                                   ['Daveigh Chase', 'Suzanne Pleshette', 'Miyu I...
# Casablanca                                      ['Humphrey Bogart', 'Ingrid Bergman', 'Paul He...
# Raiders of the Lost Ark                          ['Harrison Ford', 'Karen Allen', 'Paul Freeman']
# ...                                                                                           ...
# Manhattan Murder Mystery                           ['Woody Allen', 'Diane Keaton', 'Jerry Adler']
# Driving Miss Daisy                              ['Morgan Freeman', 'Jessica Tandy', 'Dan Aykro...
# Tootsie                                          ['Dustin Hoffman', 'Jessica Lange', 'Teri Garr']
# Back to the Future Part III                     ['Michael J. Fox', 'Christopher Lloyd', 'Mary ...
# Poltergeist                                     ['JoBeth Williams', u"Heather O'Rourke", 'Crai...
#
# [123 rows x 5 columns]

# %%
movies.loc[movies["actors_list"].str.contains("Jackie Chan")]
# Out:
#                               star_rating content_rating   genre  duration  \
# title
# The Legend of Drunken Master          7.6              R  Action       102
#
#                                                             actors_list
# title
# The Legend of Drunken Master  ['Jackie Chan', 'Ho-Sung Pak', 'Lung Ti']

# %%
titanic = pd.read_csv("titanic_train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

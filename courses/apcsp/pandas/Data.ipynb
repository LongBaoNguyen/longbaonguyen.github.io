# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a = plt.imread("sunflower.png")

# %%
a.shape
# Out:
# (113, 150, 3)

# %%
a.dtype
# Out:
# dtype('float32')

# %%
b = plt.imread("flower.jpg")

# %%
b.dtype
# Out:
# dtype('uint8')

# %%
b.shape
# Out:
# (859, 840, 3)

# %%
b
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
c = plt.imread("cup.jpg")

# %%
c.shape
# Out:
# (417, 626, 3)

# %%
c.dtpe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2395368a1341> in <module>
# ----> 1 c.dtpe
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtpe'

# %%
c.dtype
# Out:
# dtype('uint8')

# %%
c.flatten()
# Out:
# array([210, 210, 210, ..., 224, 224, 224], dtype=uint8)

# %%
d = c.flatten()
d.shape
# Out:
# (783126,)

# %%
d[1] = 190
d[2] = 225
d
e = d.reshape(417, 626, 3)

# %%
e
# Out:
# array([[[210, 190, 225],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[210, 210, 210],
#         [210, 210, 210],
#         [211, 211, 211],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        [[211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211],
#         ...,
#         [231, 231, 231],
#         [231, 231, 231],
#         [231, 231, 231]],
#
#        ...,
#
#        [[209, 209, 209],
#         [213, 213, 213],
#         [212, 212, 212],
#         ...,
#         [224, 224, 224],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        [[198, 198, 198],
#         [201, 201, 201],
#         [202, 202, 202],
#         ...,
#         [224, 224, 224],
#         [224, 224, 224],
#         [224, 224, 224]],
#
#        [[191, 191, 191],
#         [196, 196, 196],
#         [200, 200, 200],
# ...

# %%
fig, ax = plt.subplots()
ax.imshow(e)

# %%
np.savetxt("numbers.txt", e.flatten(), delimiter="\n", fmt='%u')

# %%
e.dtype
# Out:
# dtype('uint8')

# %%
e.dtype
# Out:
# dtype('uint8')

# %%
e.dtype = "int32"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d7307d1eb02a> in <module>
# ----> 1 e.dtype = "int32"
#
# ValueError: When changing to a larger dtype, its size must be a divisor of the total size in bytes of the last axis of the array.

# %%
print(e.flatten().size)
# Out:
# 783126

# %%
nums = np.loadtxt("numbers.txt", dtype="uint8")
np.reshape(nums, (417, 626, 3))
nums.shape
# Out:
# (783126,)

# %%
nums = nums.
# Out:
# dtype('float64')

# %%
nums = np.loadtxt("numbers.txt", dtype="uint8")
print(nums)
nums = nums.reshape(417, 626, 3)
fig, ax = plt.subplots()
ax.imshow(nums)
# Out:
# [210 190 225 ... 224 224 224]

# %%
nums.shape
# Out:
# (417, 626, 3)

# %%
nums.reshape()

# %%
print(1/3)
# Out:
# 0.3333333333333333

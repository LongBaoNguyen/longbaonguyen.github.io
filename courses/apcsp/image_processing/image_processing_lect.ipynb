# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.zeros((100,100,3), dtype="uint8")
a[:,25:75,0] = 255
a[25:75,:,1] = 255
fig, ax = plt.subplots()
ax.imshow(a)

# %%
img = plt.imread("flower.jpg")

# %%
a = np.zeros((100,200,3))
a[:,100:,1] = np.ones((100,100,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-937953d1801e> in <module>
#       1 a = np.zeros((100,200,3))
# ----> 2 a[:,100:,1] = np.ones((100,100,1))
#
# ValueError: could not broadcast input array from shape (100,100,1) into shape (100,100)

# %%
img.shape
# Out:
# (859, 840, 3)

# %%
fig, ax = plt.subplots()
ax.imshow(img)

# %%
print(img[200,400,:])
# Out:
# [218 222 225]

# %%
img_r = np.zeros(img.shape, dtype="uint8")
img_r[:,:,0] = img[:,:,0]

# %%
fig, ax = plt.subplots()
ax.imshow(img_r)

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
for i in range(3):
    temp = np.zeros(img.shape, dtype="uint8")
    temp[:,:,i] = img[:,:,i]
    axs[i].imshow(temp)

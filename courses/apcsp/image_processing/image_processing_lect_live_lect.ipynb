# %% [markdown]
# This is text. This is markdown.
#
# Latex(equations)
#
# $$\dfrac{-b\pm\sqrt{b^2-4ac}}{2a}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("flower.jpg")

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]]], dtype=uint8)

# %%
img.shape
# Out:
# (859, 840, 3)

# %%
fig, ax = plt.subplots()
ax.imshow(img)

# %%
img[400, 410, 0]
# Out:
# 197

# %%
img[400, 410, 1]
# Out:
# 140

# %%
img[400, 410, 2]
# Out:
# 0

# %%
img[400, 410, :]
# Out:
# array([197, 140,   0], dtype=uint8)

# %%
a = np.zeros(img.shape, dtype="uint8")
b = np.zeros(img.shape, dtype="uint8")
c = np.zeros(img.shape, dtype="uint8")

# %%
a[:, :, 0] = img[:, :, 0]
b[:, :, 1] = img[:, :, 1]
c[:, :, 2] = img[:, :, 2]

# %%
fig, ax = plt.subplots(nrows=1, ncols=3)
ax[0].imshow(a)
ax[1].imshow(b)
ax[2].imshow(c)

# %%
import numpy as np

# %%
A = np.array([[3, 2, 2],[2,3,-2]])

# %%
np.linalg.svd(A, full_matrices=True)
# Out:
# SVDResult(U=array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]]), S=array([5., 3.]), Vh=array([[-7.07106781e-01, -7.07106781e-01, -6.47932334e-17],
#        [-2.35702260e-01,  2.35702260e-01, -9.42809042e-01],
#        [-6.66666667e-01,  6.66666667e-01,  3.33333333e-01]]))

# %%
1/(4*np.sqrt(1.125))
# Out:
# np.float64(0.23570226039551587)

# %%
1/np.sqrt(18)
# Out:
# np.float64(0.23570226039551587)
